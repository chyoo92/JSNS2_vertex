# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
test = pd.read_csv('/users/yewzzang/work/make_mc_vertex/analysis/jsns2_0920_100k_10E_mc.csv')

# %%
f = np.array(test)

# %%
vtx = f[:,10:13]

# %%
pmt_charge = f[:,17:17+96]

# %%
len(ff)
# Out:
# 96

# %%
np.sort(pmt_charge)
# Out:
# array([[  1.20683 ,   1.38501 ,   2.06643 , ...,  70.9637  ,  99.8732  ,
#         138.325   ],
#        [  1.18883 ,   1.36648 ,   1.41521 , ..., 106.251   , 113.593   ,
#         304.028   ],
#        [  0.375831,   1.94213 ,   1.98846 , ...,  74.9105  , 150.366   ,
#         206.693   ],
#        ...,
#        [  0.      ,   0.      ,   0.      , ...,  20.5505  ,  57.3784  ,
#         326.766   ],
#        [  1.20672 ,   4.89165 ,   5.03369 , ...,  24.5681  ,  26.2833  ,
#          28.8673  ],
#        [  0.593669,   1.3831  ,   1.94299 , ...,  63.8926  ,  73.9932  ,
#         219.337   ]])

# %%
ff = pd.read_csv('jsns_geometry_pos.csv',header=0)

# %%
pos = []


for j in range(len(vtx)):

    pos.append(np.array(ff))

# %%
cb = np.concatenate((pmt_charge.reshape(-1,len(ff),1),np.array(pos).reshape(-1,len(ff),3)),axis=2)

# %%
cb[0].shape
# Out:
# (96, 4)

# %%
arr = np.sort(pmt_charge)

# %%
s = pmt_charge.argsort()

# %%
s
# Out:
# array([[ 0,  1,  2, ..., 93, 94, 95],
#        [ 0,  1,  2, ..., 93, 94, 95],
#        [ 0,  1,  2, ..., 93, 94, 95],
#        ...,
#        [ 0,  1,  2, ..., 93, 94, 95],
#        [ 0,  1,  2, ..., 93, 94, 95],
#        [ 0,  1,  2, ..., 93, 94, 95]])

# %%
np.sort(cb[0],axis=0)
# Out:
# array([[ 1.20683e+00, -1.83417e+03, -1.83417e+03, -1.47000e+03],
#        [ 1.38501e+00, -1.83417e+03, -1.83417e+03, -1.47000e+03],
#        [ 2.06643e+00, -1.83417e+03, -1.83417e+03, -1.47000e+03],
#        [ 2.99940e+00, -1.83417e+03, -1.83417e+03, -1.47000e+03],
#        [ 3.13976e+00, -1.83417e+03, -1.83417e+03, -1.47000e+03],
#        [ 3.20857e+00, -1.70918e+03, -1.70918e+03, -1.47000e+03],
#        [ 3.28524e+00, -1.70918e+03, -1.70918e+03, -1.47000e+03],
#        [ 3.30372e+00, -1.70918e+03, -1.70918e+03, -1.47000e+03],
#        [ 3.50051e+00, -1.70918e+03, -1.70918e+03, -1.47000e+03],
#        [ 3.52448e+00, -1.70918e+03, -1.70918e+03, -1.47000e+03],
#        [ 3.54192e+00, -1.46770e+03, -1.46770e+03, -1.47000e+03],
#        [ 3.74816e+00, -1.46770e+03, -1.46770e+03, -1.47000e+03],
#        [ 3.84862e+00, -1.46770e+03, -1.46770e+03, -1.47000e+03],
#        [ 3.92027e+00, -1.46770e+03, -1.46770e+03, -1.47000e+03],
# ...

# %%
pmt_pos = np.array(ff)

# %%
print(vtx.shape)
print(pmt_charge.shape)
print(pmt_pos.shape)
# Out:
# (99238, 3)
# (99238, 96)
# (96, 3)

# %%
### R2
diff = vtx.reshape(-1,1,3) - pmt_pos/1000
diff2 = diff[:,:,0]*diff[:,:,0]+diff[:,:,1]*diff[:,:,1]+diff[:,:,2]*diff[:,:,2]

# %%
combined = np.concatenate([pmt_charge.reshape(-1,96,1),diff2.reshape(-1,96,1)],axis=2)
combined.shape
# Out:
# (99238, 96, 2)

# %%
pmt_charge[676]==0
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
for i in range(1000):
    print(len(pmt_charge[i])==0)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
for i in range(1000):
#     plt.plot(combined[i,:,1][combined[i,:,1]<2],combined[i,:,0][combined[i,:,1]<2],'.r')
    plt.plot(combined[i,:,1],combined[i,:,0],'.r')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-1d9076a8bb8f> in <module>
#       2 #     plt.plot(combined[i,:,1][combined[i,:,1]<2],combined[i,:,0][combined[i,:,1]<2],'.r')
#       3     plt.plot(combined[i,:,1],combined[i,:,0],'.r')
# ----> 4     plt.show()
#
# ~/.conda/envs/pytorch170_pyG/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# ~/.local/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ...
