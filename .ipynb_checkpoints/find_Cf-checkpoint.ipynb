# %%
import numpy as np
import os,sys
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
import uproot4
from tqdm import tqdm

# %%
list_dir = os.listdir("/users/wonsang1995/CWDataDir_ver0_Cf_2021_3/v3/comb/FN/")

# %%
energy_all=[]
x_all=[]
y_all=[]
z_all=[]
dT_all = []
dV_all = []
Dir = "/users/wonsang1995/CWDataDir_ver0_Cf_2021_3/v3/comb/FN/"
for filename in tqdm(list_dir):
    if filename.split('.')[2][3:] == '1563': continue
    fin = uproot4.open(Dir+filename)
    energy = np.array(fin['comTree']['RecoFlux'])/(5200/8)
    vtx = np.array(fin['comTree']['RecoVertex']).T
    dT = np.array(fin['comTree']['Var1'])
    dV = np.array(fin['comTree']['Var2'])
    energy_all.append(energy)
    x_all.append(vtx[0])
    y_all.append(vtx[1])
    z_all.append(vtx[2])
    dT_all.append(dT)
    dV_all.append(dV)
energy_all=np.concatenate(energy_all)
x_all=np.concatenate(x_all)
y_all=np.concatenate(y_all)
z_all=np.concatenate(z_all)
dT_all=np.concatenate(dT_all)
dV_all=np.concatenate(dV_all)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 5558/5558 [00:10<00:00, 506.31it/s]

# %%
#cut=(np.abs(z_all)<1.25)&(dV_all>.6)
cut=(dV_all>.6)
#cut=(z_all>-2.)
#cut=(np.abs(z_all)<1.)&(np.hypot(x_all,y_all)<1.4)

# %%
plt.hist(energy_all,bins=100)
plt.xlabel('energy',fontsize=25)
plt.show()

plt.hist(dT_all,bins=100)
plt.xlabel('dT',fontsize=25)
plt.show()

plt.hist(dV_all,bins=100)
plt.xlabel('dV',fontsize=25)
plt.show()

# %%
plt.hist(energy_all[cut],bins=100)
#plt.yscale('log')
plt.xlabel('energy',fontsize=25)
plt.show()

plt.hist(dT_all[cut],bins=100)
#plt.yscale('log')
plt.xlabel('dT',fontsize=25)
plt.show()

plt.hist(dV_all[cut],bins=100)
#plt.yscale('log')
plt.xlabel('dV',fontsize=25)
plt.show()

# %%
plt.hist2d(x_all[(energy_all>12)&cut],y_all[(energy_all>12)&cut],bins=[20,20], range=[[-1.6,1.6],[-1.6,1.6]],norm = LogNorm())
plt.colorbar()
plt.xlabel('x',fontsize=25)
plt.ylabel('y',fontsize=25)
plt.show()
plt.hist(z_all[(energy_all>12)&cut], bins=20, range=[-1.25,1.25])
plt.yscale('log')
plt.xlabel('z',fontsize=25)
plt.show()
plt.hist(dT_all[(energy_all>12)&cut],bins=100)
#plt.yscale('log')
plt.xlabel('dT',fontsize=25)
plt.show()
plt.hist(dV_all[(energy_all>12)&cut],bins=100)
#plt.yscale('log')
plt.xlabel('dV',fontsize=25)
plt.show()

# %%
plt.hist2d(x_all[(energy_all<12)&(energy_all>7)&cut],y_all[(energy_all<12)&(energy_all>7)&cut],bins=[20,20], range=[[-1.6,1.6],[-1.6,1.6]],norm = LogNorm())
plt.colorbar()
plt.xlabel('x',fontsize=25)
plt.ylabel('y',fontsize=25)
plt.show()

plt.hist(z_all[(energy_all<12)&(energy_all>7)&cut], bins=20, range=[-1.25,1.25])
plt.yscale('log')
plt.xlabel('z',fontsize=25)
plt.show()

plt.hist(dT_all[(energy_all<12)&(energy_all>7)&cut],bins=100)
#plt.yscale('log')
plt.xlabel('dT',fontsize=25)
plt.show()

plt.hist(dV_all[(energy_all<12)&(energy_all>7)&cut],bins=100)
#plt.yscale('log')
plt.xlabel('dV',fontsize=25)
plt.show()

# %%
plt.hist2d(x_all[(energy_all<7)&cut],y_all[(energy_all<7)&cut],bins=[20,20], range=[[-1.6,1.6],[-1.6,1.6]],norm = LogNorm())
plt.colorbar()
plt.xlabel('x',fontsize=25)
plt.ylabel('y',fontsize=25)
plt.show()

plt.hist(z_all[(energy_all<7)&cut], bins=20, range=[-1.25,1.25])
plt.yscale('log')
plt.xlabel('z',fontsize=25)
plt.show()

plt.hist(dT_all[(energy_all<7)&cut],bins=100)
#plt.yscale('log')
plt.xlabel('dT',fontsize=25)
plt.show()

plt.hist(dV_all[(energy_all<7)&cut],bins=100)
#plt.yscale('log')
plt.xlabel('dV',fontsize=25)
plt.show()
