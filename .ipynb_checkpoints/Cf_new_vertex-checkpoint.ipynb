# %%
import uproot
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import h5py

# %%
path = '/users/wonsang1995/CWDataDir_ver0_Cf_2021_3/v3/comb/FN/'
# path = '/users/wonsang1995/CWDataDir_ver0_Cf_2021_noOverlapped_vetoQcut_E10to60/v3/comb/FN/'

# %%
files = os.listdir(path)

# %%
files
# Out:
# ['comb.debug.r001519.f00005.root',
#  'comb.debug.r001563.f00148.root',
#  'comb.debug.r001563.f02252.root',
#  'comb.debug.r001563.f03274.root',
#  'comb.debug.r001563.f04525.root',
#  'comb.debug.r001563.f01249.root',
#  'comb.debug.r001563.f02087.root',
#  'comb.debug.r001563.f02501.root',
#  'comb.debug.r001511.f00048.root',
#  'comb.debug.r001563.f02799.root',
#  'comb.debug.r001563.f02107.root',
#  'comb.debug.r001521.f00003.root',
#  'comb.debug.r001563.f04412.root',
#  'comb.debug.r001563.f01074.root',
#  'comb.debug.r001563.f02783.root',
#  'comb.debug.r001522.f00020.root',
#  'comb.debug.r001563.f02877.root',
#  'comb.debug.r001563.f02060.root',
#  'comb.debug.r001563.f00023.root',
#  'comb.debug.r001563.f00152.root',
#  'comb.debug.r001563.f03611.root',
#  'comb.debug.r001563.f01754.root',
#  'comb.debug.r001563.f01447.root',
#  'comb.debug.r001563.f03153.root',
#  'comb.debug.r001563.f00697.root',
#  'comb.debug.r001563.f00691.root',
#  'comb.debug.r001563.f01640.root',
#  'comb.debug.r001563.f00393.root',
#  'comb.debug.r001563.f03269.root',
#  'comb.debug.r001563.f01142.root',
#  'comb.debug.r001563.f02195.root',
#  'comb.debug.r001563.f01081.root',
#  'comb.debug.r001563.f00321.root',
#  'comb.debug.r001517.f00041.root',
#  'comb.debug.r001563.f00039.root',
#  'comb.debug.r001563.f03698.root',
#  'comb.debug.r001563.f01300.root',
#  'comb.debug.r001563.f01935.root',
#  'comb.debug.r001563.f00043.root',
#  'comb.debug.r001563.f03494.root',
#  'comb.debug.r001563.f04136.root',
#  'comb.debug.r001563.f00509.root',
#  'comb.debug.r001563.f03712.root',
#  'comb.debug.r001563.f01831.root',
#  'comb.debug.r001563.f04277.root',
#  'comb.debug.r001522.f00030.root',
#  'comb.debug.r001563.f00744.root',
#  'comb.debug.r001512.f00028.root',
#  'comb.debug.r001563.f03610.root',
#  'comb.debug.r001563.f00224.root',
#  'comb.debug.r001563.f03416.root',
#  'comb.debug.r001563.f01774.root',
#  'comb.debug.r001563.f04711.root',
#  'comb.debug.r001522.f00040.root',
#  'comb.debug.r001563.f04268.root',
#  'comb.debug.r001563.f03597.root',
#  'comb.debug.r001563.f02590.root',
#  'comb.debug.r001563.f02395.root',
#  'comb.debug.r001563.f02896.root',
#  'comb.debug.r001563.f00009.root',
#  'comb.debug.r001563.f00386.root',
#  'comb.debug.r001563.f00154.root',
#  'comb.debug.r001563.f03250.root',
#  'comb.debug.r001563.f04521.root',
#  'comb.debug.r001563.f00655.root',
#  'comb.debug.r001563.f02283.root',
#  'comb.debug.r001512.f00034.root',
#  'comb.debug.r001563.f02146.root',
#  'comb.debug.r001563.f02600.root',
#  'comb.debug.r001563.f04427.root',
#  'comb.debug.r001563.f04630.root',
#  'comb.debug.r001512.f00000.root',
#  'comb.debug.r001563.f02370.root',
#  'comb.debug.r001522.f00041.root',
#  'comb.debug.r001563.f04556.root',
#  'comb.debug.r001563.f02586.root',
#  'comb.debug.r001563.f04130.root',
#  'comb.debug.r001563.f03048.root',
#  'comb.debug.r001563.f01679.root',
#  'comb.debug.r001523.f00004.root',
#  'comb.debug.r001522.f00007.root',
#  'comb.debug.r001563.f01885.root',
#  'comb.debug.r001563.f03349.root',
#  'comb.debug.r001563.f04402.root',
#  'comb.debug.r001563.f04787.root',
#  'comb.debug.r001563.f02066.root',
#  'comb.debug.r001563.f00565.root',
#  'comb.debug.r001563.f01147.root',
#  'comb.debug.r001563.f01167.root',
#  'comb.debug.r001563.f02051.root',
#  'comb.debug.r001563.f03728.root',
#  'comb.debug.r001563.f04066.root',
#  'comb.debug.r001563.f01910.root',
#  'comb.debug.r001563.f01429.root',
#  'comb.debug.r001511.f00039.root',
#  'comb.debug.r001513.f00013.root',
#  'comb.debug.r001563.f04056.root',
#  'comb.debug.r001563.f03763.root',
#  'comb.debug.r001563.f02042.root',
#  'comb.debug.r001563.f04797.root',
#  'comb.debug.r001563.f04052.root',
#  'comb.debug.r001563.f02294.root',
#  'comb.debug.r001563.f02437.root',
#  'comb.debug.r001563.f01927.root',
#  'comb.debug.r001563.f00753.root',
#  'comb.debug.r001563.f02096.root',
#  'comb.debug.r001563.f00293.root',
#  'comb.debug.r001563.f02120.root',
#  'comb.debug.r001563.f03350.root',
#  'comb.debug.r001563.f02469.root',
#  'comb.debug.r001563.f04180.root',
#  'comb.debug.r001563.f00151.root',
#  'comb.debug.r001563.f02227.root',
#  'comb.debug.r001563.f01279.root',
#  'comb.debug.r001563.f00329.root',
#  'comb.debug.r001563.f01077.root',
#  'comb.debug.r001563.f03952.root',
#  'comb.debug.r001563.f00105.root',
#  'comb.debug.r001563.f00831.root',
#  'comb.debug.r001563.f03747.root',
#  'comb.debug.r001521.f00016.root',
#  'comb.debug.r001517.f00037.root',
#  'comb.debug.r001511.f00005.root',
#  'comb.debug.r001563.f00380.root',
#  'comb.debug.r001513.f00039.root',
#  'comb.debug.r001510.f00051.root',
#  'comb.debug.r001563.f03092.root',
#  'comb.debug.r001563.f00168.root',
#  'comb.debug.r001563.f01258.root',
#  'comb.debug.r001563.f01787.root',
#  'comb.debug.r001563.f01385.root',
#  'comb.debug.r001563.f04862.root',
#  'comb.debug.r001563.f00503.root',
#  'comb.debug.r001563.f03504.root',
#  'comb.debug.r001563.f01783.root',
#  'comb.debug.r001563.f00670.root',
#  'comb.debug.r001563.f00051.root',
#  'comb.debug.r001563.f03136.root',
#  'comb.debug.r001563.f00117.root',
#  'comb.debug.r001512.f00038.root',
#  'comb.debug.r001563.f03167.root',
#  'comb.debug.r001563.f02845.root',
#  'comb.debug.r001563.f00596.root',
#  'comb.debug.r001563.f03102.root',
#  'comb.debug.r001563.f01814.root',
#  'comb.debug.r001563.f02790.root',
#  'comb.debug.r001563.f01843.root',
#  'comb.debug.r001563.f03969.root',
#  'comb.debug.r001563.f02905.root',
#  'comb.debug.r001563.f04592.root',
#  'comb.debug.r001563.f01566.root',
#  'comb.debug.r001563.f01435.root',
#  'comb.debug.r001563.f02667.root',
#  'comb.debug.r001563.f03828.root',
#  'comb.debug.r001563.f03415.root',
#  'comb.debug.r001563.f01603.root',
#  'comb.debug.r001563.f00715.root',
#  'comb.debug.r001563.f01481.root',
#  'comb.debug.r001563.f01145.root',
#  'comb.debug.r001563.f02215.root',
#  'comb.debug.r001563.f03998.root',
#  'comb.debug.r001563.f00240.root',
#  'comb.debug.r001563.f02117.root',
#  'comb.debug.r001563.f03672.root',
#  'comb.debug.r001563.f04076.root',
#  'comb.debug.r001563.f00667.root',
#  'comb.debug.r001563.f03452.root',
#  'comb.debug.r001563.f01362.root',
#  'comb.debug.r001563.f04184.root',
#  'comb.debug.r001563.f04241.root',
#  'comb.debug.r001563.f02443.root',
#  'comb.debug.r001563.f01054.root',
#  'comb.debug.r001563.f03093.root',
#  'comb.debug.r001563.f03301.root',
#  'comb.debug.r001563.f02377.root',
#  'comb.debug.r001563.f03295.root',
#  'comb.debug.r001510.f00024.root',
#  'comb.debug.r001563.f00353.root',
#  'comb.debug.r001563.f00531.root',
#  'comb.debug.r001563.f02090.root',
#  'comb.debug.r001563.f02819.root',
#  'comb.debug.r001563.f03254.root',
#  'comb.debug.r001563.f01471.root',
#  'comb.debug.r001563.f00174.root',
#  'comb.debug.r001563.f00453.root',
#  'comb.debug.r001563.f02524.root',
#  'comb.debug.r001563.f00417.root',
#  'comb.debug.r001563.f00176.root',
#  'comb.debug.r001563.f03609.root',
#  'comb.debug.r001563.f04433.root',
#  'comb.debug.r001563.f00173.root',
#  'comb.debug.r001563.f04060.root',
#  'comb.debug.r001563.f04857.root',
#  'comb.debug.r001563.f04784.root',
#  'comb.debug.r001563.f02920.root',
#  'comb.debug.r001563.f00346.root',
#  'comb.debug.r001563.f01988.root',
#  'comb.debug.r001563.f03622.root',
#  'comb.debug.r001563.f02840.root',
#  'comb.debug.r001506.f00026.root',
#  'comb.debug.r001563.f02224.root',
#  'comb.debug.r001563.f01498.root',
#  'comb.debug.r001506.f00016.root',
#  'comb.debug.r001563.f04194.root',
#  'comb.debug.r001563.f01618.root',
#  'comb.debug.r001563.f01901.root',
#  'comb.debug.r001563.f03915.root',
#  'comb.debug.r001563.f02116.root',
#  'comb.debug.r001563.f01071.root',
#  'comb.debug.r001563.f03052.root',
#  'comb.debug.r001563.f02185.root',
#  'comb.debug.r001563.f00205.root',
#  'comb.debug.r001563.f02974.root',
#  'comb.debug.r001563.f01505.root',
#  'comb.debug.r001563.f03871.root',
#  'comb.debug.r001563.f01521.root',
#  'comb.debug.r001563.f02358.root',
#  'comb.debug.r001522.f00027.root',
#  'comb.debug.r001520.f00035.root',
#  'comb.debug.r001563.f01937.root',
#  'comb.debug.r001563.f02103.root',
#  'comb.debug.r001563.f03928.root',
#  'comb.debug.r001563.f03333.root',
#  'comb.debug.r001563.f04150.root',
#  'comb.debug.r001563.f00783.root',
#  'comb.debug.r001563.f04829.root',
#  'comb.debug.r001563.f03490.root',
#  'comb.debug.r001563.f04088.root',
#  'comb.debug.r001563.f04111.root',
#  'comb.debug.r001563.f04610.root',
#  'comb.debug.r001563.f03841.root',
#  'comb.debug.r001563.f02787.root',
#  'comb.debug.r001563.f01585.root',
#  'comb.debug.r001563.f01193.root',
#  'comb.debug.r001519.f00020.root',
#  'comb.debug.r001563.f01649.root',
#  'comb.debug.r001563.f03681.root',
#  'comb.debug.r001563.f03993.root',
#  'comb.debug.r001563.f03021.root',
#  'comb.debug.r001563.f04523.root',
#  'comb.debug.r001563.f01253.root',
#  'comb.debug.r001563.f02987.root',
#  'comb.debug.r001563.f02162.root',
#  'comb.debug.r001563.f04032.root',
#  'comb.debug.r001522.f00028.root',
#  'comb.debug.r001563.f02389.root',
#  'comb.debug.r001563.f00045.root',
#  'comb.debug.r001563.f00156.root',
#  'comb.debug.r001563.f03996.root',
#  'comb.debug.r001523.f00006.root',
#  'comb.debug.r001519.f00027.root',
#  'comb.debug.r001563.f03768.root',
#  'comb.debug.r001509.f00011.root',
#  'comb.debug.r001563.f00478.root',
#  'comb.debug.r001563.f02328.root',
#  'comb.debug.r001563.f03497.root',
#  'comb.debug.r001509.f00035.root',
#  'comb.debug.r001518.f00022.root',
#  'comb.debug.r001563.f04467.root',
#  'comb.debug.r001563.f02174.root',
#  'comb.debug.r001518.f00010.root',
#  'comb.debug.r001519.f00043.root',
#  'comb.debug.r001563.f00690.root',
#  'comb.debug.r001563.f03955.root',
#  'comb.debug.r001522.f00011.root',
#  'comb.debug.r001563.f02440.root',
#  'comb.debug.r001563.f02333.root',
#  'comb.debug.r001563.f00459.root',
#  'comb.debug.r001563.f04055.root',
#  'comb.debug.r001563.f03630.root',
#  'comb.debug.r001521.f00007.root',
#  'comb.debug.r001563.f03159.root',
#  'comb.debug.r001563.f01329.root',
#  'comb.debug.r001563.f02184.root',
#  'comb.debug.r001563.f00460.root',
#  'comb.debug.r001563.f03932.root',
#  'comb.debug.r001563.f02459.root',
#  'comb.debug.r001563.f03068.root',
#  'comb.debug.r001517.f00027.root',
#  'comb.debug.r001563.f02284.root',
#  'comb.debug.r001563.f00832.root',
#  'comb.debug.r001563.f02157.root',
#  'comb.debug.r001563.f02073.root',
#  'comb.debug.r001512.f00035.root',
#  'comb.debug.r001563.f00602.root',
#  'comb.debug.r001520.f00052.root',
#  'comb.debug.r001563.f04070.root',
#  'comb.debug.r001563.f03077.root',
#  'comb.debug.r001563.f00374.root',
#  'comb.debug.r001563.f01645.root',
#  'comb.debug.r001563.f03866.root',
#  'comb.debug.r001563.f00587.root',
#  'comb.debug.r001563.f04514.root',
#  'comb.debug.r001563.f04729.root',
#  'comb.debug.r001563.f04552.root',
#  'comb.debug.r001563.f00059.root',
#  'comb.debug.r001510.f00019.root',
#  'comb.debug.r001513.f00015.root',
#  'comb.debug.r001563.f03467.root',
#  'comb.debug.r001563.f01973.root',
#  'comb.debug.r001563.f00696.root',
#  'comb.debug.r001563.f02480.root',
#  'comb.debug.r001563.f01993.root',
#  'comb.debug.r001563.f04069.root',
#  'comb.debug.r001519.f00044.root',
#  'comb.debug.r001563.f00233.root',
#  'comb.debug.r001563.f01292.root',
#  'comb.debug.r001563.f04684.root',
#  'comb.debug.r001563.f04798.root',
#  'comb.debug.r001563.f00928.root',
#  'comb.debug.r001563.f04579.root',
#  'comb.debug.r001563.f00862.root',
#  'comb.debug.r001563.f03692.root',
#  'comb.debug.r001563.f01408.root',
#  'comb.debug.r001563.f01622.root',
#  'comb.debug.r001509.f00034.root',
#  'comb.debug.r001563.f04250.root',
#  'comb.debug.r001563.f00881.root',
#  'comb.debug.r001563.f00558.root',
#  'comb.debug.r001563.f03908.root',
#  'comb.debug.r001563.f00129.root',
#  'comb.debug.r001563.f00721.root',
#  'comb.debug.r001521.f00039.root',
#  'comb.debug.r001563.f01842.root',
#  'comb.debug.r001510.f00037.root',
#  'comb.debug.r001563.f01869.root',
#  'comb.debug.r001563.f02164.root',
#  'comb.debug.r001563.f03156.root',
#  'comb.debug.r001563.f01488.root',
#  'comb.debug.r001521.f00032.root',
#  'comb.debug.r001563.f00443.root',
#  'comb.debug.r001563.f04841.root',
#  'comb.debug.r001563.f02969.root',
#  'comb.debug.r001509.f00005.root',
#  'comb.debug.r001563.f01006.root',
#  'comb.debug.r001563.f02710.root',
#  'comb.debug.r001520.f00047.root',
#  'comb.debug.r001563.f00872.root',
#  'comb.debug.r001563.f02183.root',
#  'comb.debug.r001563.f02684.root',
#  'comb.debug.r001563.f04435.root',
#  'comb.debug.r001563.f02872.root',
#  'comb.debug.r001563.f03001.root',
#  'comb.debug.r001513.f00030.root',
#  'comb.debug.r001563.f04749.root',
#  'comb.debug.r001563.f00921.root',
#  'comb.debug.r001563.f04769.root',
#  'comb.debug.r001563.f04517.root',
#  'comb.debug.r001517.f00026.root',
#  'comb.debug.r001563.f03253.root',
#  'comb.debug.r001563.f01612.root',
#  'comb.debug.r001563.f04707.root',
#  'comb.debug.r001563.f02454.root',
#  'comb.debug.r001563.f02425.root',
#  'comb.debug.r001563.f02455.root',
#  'comb.debug.r001563.f00520.root',
#  'comb.debug.r001520.f00026.root',
#  'comb.debug.r001563.f00840.root',
#  'comb.debug.r001563.f00017.root',
#  'comb.debug.r001563.f01287.root',
#  'comb.debug.r001563.f03934.root',
#  'comb.debug.r001563.f01298.root',
#  'comb.debug.r001563.f01636.root',
#  'comb.debug.r001563.f01175.root',
#  'comb.debug.r001563.f03369.root',
#  'comb.debug.r001563.f01733.root',
#  'comb.debug.r001563.f01848.root',
#  'comb.debug.r001563.f00197.root',
#  'comb.debug.r001563.f00324.root',
#  'comb.debug.r001563.f03036.root',
#  'comb.debug.r001563.f00799.root',
#  'comb.debug.r001563.f02301.root',
#  'comb.debug.r001563.f02566.root',
#  'comb.debug.r001563.f00066.root',
#  'comb.debug.r001563.f03971.root',
#  'comb.debug.r001563.f03204.root',
#  'comb.debug.r001563.f01717.root',
#  'comb.debug.r001563.f00554.root',
#  'comb.debug.r001563.f02811.root',
#  'comb.debug.r001563.f02965.root',
#  'comb.debug.r001563.f04836.root',
#  'comb.debug.r001563.f01632.root',
#  'comb.debug.r001563.f00102.root',
#  'comb.debug.r001563.f00904.root',
#  'comb.debug.r001563.f01002.root',
#  'comb.debug.r001563.f01512.root',
#  'comb.debug.r001563.f02942.root',
#  'comb.debug.r001563.f01934.root',
#  'comb.debug.r001563.f04571.root',
#  'comb.debug.r001509.f00051.root',
#  'comb.debug.r001563.f03855.root',
#  'comb.debug.r001563.f04112.root',
#  'comb.debug.r001563.f04674.root',
#  'comb.debug.r001563.f02270.root',
#  'comb.debug.r001563.f00251.root',
#  'comb.debug.r001563.f00661.root',
#  'comb.debug.r001563.f00434.root',
#  'comb.debug.r001512.f00025.root',
#  'comb.debug.r001563.f01220.root',
#  'comb.debug.r001563.f03392.root',
#  'comb.debug.r001518.f00001.root',
#  'comb.debug.r001563.f01576.root',
#  'comb.debug.r001563.f03069.root',
#  'comb.debug.r001563.f04010.root',
#  'comb.debug.r001563.f02970.root',
#  'comb.debug.r001563.f02192.root',
#  'comb.debug.r001522.f00039.root',
#  'comb.debug.r001563.f01680.root',
#  'comb.debug.r001563.f03844.root',
#  'comb.debug.r001563.f01588.root',
#  'comb.debug.r001563.f03476.root',
#  'comb.debug.r001563.f03979.root',
#  'comb.debug.r001523.f00048.root',
#  'comb.debug.r001520.f00032.root',
#  'comb.debug.r001563.f02574.root',
#  'comb.debug.r001563.f03149.root',
#  'comb.debug.r001563.f04626.root',
#  'comb.debug.r001563.f01155.root',
#  'comb.debug.r001509.f00022.root',
#  'comb.debug.r001563.f04344.root',
#  'comb.debug.r001563.f00473.root',
#  'comb.debug.r001563.f00281.root',
#  'comb.debug.r001563.f00283.root',
#  'comb.debug.r001511.f00018.root',
#  'comb.debug.r001563.f01255.root',
#  'comb.debug.r001563.f02562.root',
#  'comb.debug.r001563.f00607.root',
#  'comb.debug.r001563.f01178.root',
#  'comb.debug.r001563.f04295.root',
#  'comb.debug.r001519.f00001.root',
#  'comb.debug.r001563.f01506.root',
#  'comb.debug.r001563.f03872.root',
#  'comb.debug.r001563.f02136.root',
#  'comb.debug.r001563.f02239.root',
#  'comb.debug.r001563.f03180.root',
#  'comb.debug.r001518.f00004.root',
#  'comb.debug.r001563.f03637.root',
#  'comb.debug.r001563.f04461.root',
#  'comb.debug.r001563.f01136.root',
#  'comb.debug.r001563.f03079.root',
#  'comb.debug.r001521.f00028.root',
#  'comb.debug.r001519.f00034.root',
#  'comb.debug.r001521.f00026.root',
#  'comb.debug.r001563.f04149.root',
#  'comb.debug.r001563.f00261.root',
#  'comb.debug.r001563.f02839.root',
#  'comb.debug.r001563.f00499.root',
#  'comb.debug.r001563.f00057.root',
#  'comb.debug.r001513.f00046.root',
#  'comb.debug.r001563.f03212.root',
#  'comb.debug.r001563.f01367.root',
#  'comb.debug.r001563.f03846.root',
#  'comb.debug.r001563.f03938.root',
#  'comb.debug.r001563.f00273.root',
#  'comb.debug.r001563.f02110.root',
#  'comb.debug.r001563.f02552.root',
#  'comb.debug.r001563.f01100.root',
#  'comb.debug.r001563.f02645.root',
#  'comb.debug.r001563.f01189.root',
#  'comb.debug.r001563.f04157.root',
#  'comb.debug.r001563.f02271.root',
#  'comb.debug.r001563.f02384.root',
#  'comb.debug.r001563.f02916.root',
#  'comb.debug.r001563.f01747.root',
#  'comb.debug.r001563.f03951.root',
#  'comb.debug.r001563.f00793.root',
#  'comb.debug.r001563.f01523.root',
#  'comb.debug.r001563.f01606.root',
#  'comb.debug.r001506.f00011.root',
#  'comb.debug.r001563.f03732.root',
#  'comb.debug.r001563.f01324.root',
#  'comb.debug.r001563.f03765.root',
#  'comb.debug.r001563.f02603.root',
#  'comb.debug.r001563.f01941.root',
#  'comb.debug.r001563.f04436.root',
#  'comb.debug.r001563.f04348.root',
#  'comb.debug.r001563.f01803.root',
#  'comb.debug.r001563.f00320.root',
#  'comb.debug.r001563.f00419.root',
#  'comb.debug.r001563.f04368.root',
#  'comb.debug.r001563.f04802.root',
#  'comb.debug.r001563.f03314.root',
#  'comb.debug.r001563.f00286.root',
#  'comb.debug.r001512.f00037.root',
#  'comb.debug.r001563.f04049.root',
#  'comb.debug.r001563.f00355.root',
#  'comb.debug.r001563.f00551.root',
#  'comb.debug.r001563.f03972.root',
#  'comb.debug.r001563.f02511.root',
#  'comb.debug.r001563.f03723.root',
#  'comb.debug.r001563.f02428.root',
#  'comb.debug.r001506.f00024.root',
#  'comb.debug.r001563.f02404.root',
#  'comb.debug.r001563.f01194.root',
#  'comb.debug.r001563.f02378.root',
#  'comb.debug.r001563.f00879.root',
#  'comb.debug.r001563.f03176.root',
#  'comb.debug.r001563.f01316.root',
#  'comb.debug.r001563.f00413.root',
#  'comb.debug.r001563.f01404.root',
#  'comb.debug.r001563.f04647.root',
#  'comb.debug.r001563.f03334.root',
#  'comb.debug.r001517.f00017.root',
#  'comb.debug.r001563.f01102.root',
#  'comb.debug.r001563.f01527.root',
#  'comb.debug.r001511.f00033.root',
#  'comb.debug.r001563.f02015.root',
#  'comb.debug.r001563.f00371.root',
#  'comb.debug.r001522.f00043.root',
#  'comb.debug.r001563.f03602.root',
#  'comb.debug.r001519.f00022.root',
#  'comb.debug.r001563.f02720.root',
#  'comb.debug.r001563.f04726.root',
#  'comb.debug.r001563.f04554.root',
#  'comb.debug.r001563.f00614.root',
#  'comb.debug.r001563.f04562.root',
#  'comb.debug.r001563.f03834.root',
#  'comb.debug.r001563.f01011.root',
#  'comb.debug.r001563.f03081.root',
#  'comb.debug.r001509.f00023.root',
#  'comb.debug.r001563.f03424.root',
#  'comb.debug.r001563.f04027.root',
#  'comb.debug.r001563.f00640.root',
#  'comb.debug.r001563.f03433.root',
#  'comb.debug.r001563.f02854.root',
#  'comb.debug.r001563.f02577.root',
#  'comb.debug.r001563.f01340.root',
#  'comb.debug.r001563.f04590.root',
#  'comb.debug.r001563.f00600.root',
#  'comb.debug.r001563.f02531.root',
#  'comb.debug.r001563.f01108.root',
#  'comb.debug.r001563.f02742.root',
#  'comb.debug.r001563.f00384.root',
#  'comb.debug.r001563.f01323.root',
#  'comb.debug.r001563.f04623.root',
#  'comb.debug.r001523.f00029.root',
#  'comb.debug.r001563.f04613.root',
#  'comb.debug.r001563.f00484.root',
#  'comb.debug.r001563.f00698.root',
#  'comb.debug.r001517.f00050.root',
#  'comb.debug.r001563.f04002.root',
#  'comb.debug.r001563.f01545.root',
#  'comb.debug.r001506.f00045.root',
#  'comb.debug.r001563.f01165.root',
#  'comb.debug.r001563.f01043.root',
#  'comb.debug.r001512.f00052.root',
#  'comb.debug.r001563.f02595.root',
#  'comb.debug.r001513.f00002.root',
#  'comb.debug.r001563.f03218.root',
#  'comb.debug.r001563.f03407.root',
#  'comb.debug.r001563.f01184.root',
#  'comb.debug.r001517.f00042.root',
#  'comb.debug.r001563.f03546.root',
#  'comb.debug.r001563.f04291.root',
#  'comb.debug.r001563.f01304.root',
#  'comb.debug.r001563.f00848.root',
#  'comb.debug.r001563.f03356.root',
#  'comb.debug.r001563.f04074.root',
#  'comb.debug.r001563.f03522.root',
#  'comb.debug.r001563.f00493.root',
#  'comb.debug.r001563.f00314.root',
#  'comb.debug.r001563.f02258.root',
#  'comb.debug.r001563.f04048.root',
#  'comb.debug.r001563.f02650.root',
#  'comb.debug.r001563.f01528.root',
#  'comb.debug.r001563.f02922.root',
#  'comb.debug.r001563.f00617.root',
#  'comb.debug.r001563.f03526.root',
#  'comb.debug.r001563.f00755.root',
#  'comb.debug.r001563.f03469.root',
#  'comb.debug.r001563.f04121.root',
#  'comb.debug.r001563.f02027.root',
#  'comb.debug.r001563.f02788.root',
#  'comb.debug.r001563.f03234.root',
#  'comb.debug.r001563.f04742.root',
#  'comb.debug.r001523.f00042.root',
#  'comb.debug.r001563.f03864.root',
#  'comb.debug.r001563.f01591.root',
#  'comb.debug.r001563.f03901.root',
#  'comb.debug.r001511.f00013.root',
#  'comb.debug.r001563.f04852.root',
#  'comb.debug.r001563.f00923.root',
#  'comb.debug.r001517.f00014.root',
#  'comb.debug.r001563.f00217.root',
#  'comb.debug.r001563.f03480.root',
#  'comb.debug.r001563.f04765.root',
#  'comb.debug.r001563.f01746.root',
#  'comb.debug.r001563.f02327.root',
#  'comb.debug.r001563.f04583.root',
#  'comb.debug.r001563.f03902.root',
#  'comb.debug.r001563.f00507.root',
#  'comb.debug.r001563.f00076.root',
#  'comb.debug.r001563.f02204.root',
#  'comb.debug.r001563.f01251.root',
#  'comb.debug.r001563.f02693.root',
#  'comb.debug.r001563.f00398.root',
#  'comb.debug.r001563.f02475.root',
#  'comb.debug.r001563.f01389.root',
#  'comb.debug.r001563.f04673.root',
#  'comb.debug.r001563.f01918.root',
#  'comb.debug.r001563.f03378.root',
#  'comb.debug.r001563.f04205.root',
#  'comb.debug.r001563.f02725.root',
#  'comb.debug.r001563.f02365.root',
#  'comb.debug.r001563.f01920.root',
#  'comb.debug.r001513.f00004.root',
#  'comb.debug.r001563.f02712.root',
#  'comb.debug.r001563.f02885.root',
#  'comb.debug.r001563.f01342.root',
#  'comb.debug.r001563.f01615.root',
#  'comb.debug.r001563.f02774.root',
#  'comb.debug.r001563.f00322.root',
#  'comb.debug.r001563.f00707.root',
#  'comb.debug.r001563.f02299.root',
#  'comb.debug.r001563.f04425.root',
#  'comb.debug.r001563.f03701.root',
#  'comb.debug.r001563.f02646.root',
#  'comb.debug.r001563.f04141.root',
#  'comb.debug.r001563.f04410.root',
#  'comb.debug.r001563.f03578.root',
#  'comb.debug.r001563.f02236.root',
#  'comb.debug.r001563.f04499.root',
#  'comb.debug.r001512.f00017.root',
#  'comb.debug.r001563.f01326.root',
#  'comb.debug.r001563.f02036.root',
#  'comb.debug.r001563.f04687.root',
#  'comb.debug.r001563.f01008.root',
#  'comb.debug.r001511.f00022.root',
#  'comb.debug.r001563.f03595.root',
#  'comb.debug.r001563.f00804.root',
#  'comb.debug.r001563.f04077.root',
#  'comb.debug.r001563.f00506.root',
#  'comb.debug.r001563.f04045.root',
#  'comb.debug.r001563.f03789.root',
#  'comb.debug.r001563.f02986.root',
#  'comb.debug.r001563.f04345.root',
#  'comb.debug.r001563.f00651.root',
#  'comb.debug.r001563.f04789.root',
#  'comb.debug.r001563.f03225.root',
#  'comb.debug.r001563.f04793.root',
#  'comb.debug.r001563.f01274.root',
#  'comb.debug.r001563.f02732.root',
#  'comb.debug.r001563.f03096.root',
#  'comb.debug.r001563.f01704.root',
#  'comb.debug.r001563.f01031.root',
#  'comb.debug.r001563.f03126.root',
#  'comb.debug.r001511.f00016.root',
#  'comb.debug.r001563.f02855.root',
#  'comb.debug.r001563.f01305.root',
#  'comb.debug.r001518.f00024.root',
#  'comb.debug.r001563.f03795.root',
#  'comb.debug.r001563.f03778.root',
#  'comb.debug.r001563.f04283.root',
#  'comb.debug.r001563.f04263.root',
#  'comb.debug.r001517.f00031.root',
#  'comb.debug.r001563.f02302.root',
#  'comb.debug.r001563.f03929.root',
#  'comb.debug.r001517.f00021.root',
#  'comb.debug.r001522.f00031.root',
#  'comb.debug.r001563.f01610.root',
#  'comb.debug.r001518.f00048.root',
#  'comb.debug.r001563.f01720.root',
#  'comb.debug.r001563.f00486.root',
#  'comb.debug.r001563.f01826.root',
#  'comb.debug.r001563.f02201.root',
#  'comb.debug.r001563.f04284.root',
#  'comb.debug.r001563.f00869.root',
#  'comb.debug.r001512.f00012.root',
#  'comb.debug.r001563.f03146.root',
#  'comb.debug.r001506.f00030.root',
#  'comb.debug.r001563.f01917.root',
#  'comb.debug.r001563.f03055.root',
#  'comb.debug.r001563.f03753.root',
#  'comb.debug.r001563.f04124.root',
#  'comb.debug.r001563.f03022.root',
#  'comb.debug.r001563.f00313.root',
#  'comb.debug.r001563.f00728.root',
#  'comb.debug.r001563.f04867.root',
#  'comb.debug.r001563.f02045.root',
#  'comb.debug.r001563.f02637.root',
#  'comb.debug.r001563.f01896.root',
#  'comb.debug.r001563.f00383.root',
#  'comb.debug.r001517.f00005.root',
#  'comb.debug.r001519.f00050.root',
#  'comb.debug.r001563.f00285.root',
#  'comb.debug.r001563.f00471.root',
#  'comb.debug.r001563.f00220.root',
#  'comb.debug.r001563.f03799.root',
#  'comb.debug.r001563.f04839.root',
#  'comb.debug.r001563.f01698.root',
#  'comb.debug.r001563.f03819.root',
#  'comb.debug.r001563.f03970.root',
#  'comb.debug.r001563.f02297.root',
#  'comb.debug.r001563.f02371.root',
#  'comb.debug.r001563.f01517.root',
#  'comb.debug.r001563.f00898.root',
#  'comb.debug.r001563.f02334.root',
#  'comb.debug.r001563.f04589.root',
#  'comb.debug.r001563.f02305.root',
#  'comb.debug.r001517.f00029.root',
#  'comb.debug.r001563.f01065.root',
#  'comb.debug.r001563.f04746.root',
#  'comb.debug.r001563.f04001.root',
#  'comb.debug.r001563.f02746.root',
#  'comb.debug.r001563.f00212.root',
#  'comb.debug.r001563.f01114.root',
#  'comb.debug.r001563.f04261.root',
#  'comb.debug.r001563.f02519.root',
#  'comb.debug.r001563.f00336.root',
#  'comb.debug.r001563.f04404.root',
#  'comb.debug.r001523.f00019.root',
#  'comb.debug.r001563.f04201.root',
#  'comb.debug.r001563.f01750.root',
#  'comb.debug.r001563.f02900.root',
#  'comb.debug.r001563.f02216.root',
#  'comb.debug.r001563.f01174.root',
#  'comb.debug.r001563.f04752.root',
#  'comb.debug.r001563.f02837.root',
#  'comb.debug.r001563.f04031.root',
#  'comb.debug.r001563.f01867.root',
#  'comb.debug.r001563.f00109.root',
#  'comb.debug.r001563.f03949.root',
#  'comb.debug.r001563.f02280.root',
#  'comb.debug.r001563.f00580.root',
#  'comb.debug.r001563.f03423.root',
#  'comb.debug.r001563.f04578.root',
#  'comb.debug.r001563.f01171.root',
#  'comb.debug.r001563.f02189.root',
#  'comb.debug.r001563.f04597.root',
#  'comb.debug.r001563.f03589.root',
#  'comb.debug.r001563.f01331.root',
#  'comb.debug.r001563.f04720.root',
#  'comb.debug.r001563.f04864.root',
#  'comb.debug.r001563.f02966.root',
#  'comb.debug.r001510.f00031.root',
#  'comb.debug.r001563.f00672.root',
#  'comb.debug.r001563.f02046.root',
#  'comb.debug.r001563.f00723.root',
#  'comb.debug.r001563.f00347.root',
#  'comb.debug.r001563.f02728.root',
#  'comb.debug.r001563.f03807.root',
#  'comb.debug.r001522.f00016.root',
#  'comb.debug.r001563.f02112.root',
#  'comb.debug.r001563.f04860.root',
#  'comb.debug.r001563.f04701.root',
#  'comb.debug.r001563.f04054.root',
#  'comb.debug.r001563.f00572.root',
#  'comb.debug.r001563.f00943.root',
#  'comb.debug.r001563.f02130.root',
#  'comb.debug.r001563.f03440.root',
#  'comb.debug.r001563.f03802.root',
#  'comb.debug.r001563.f00047.root',
#  'comb.debug.r001511.f00010.root',
#  'comb.debug.r001522.f00038.root',
#  'comb.debug.r001563.f03051.root',
#  'comb.debug.r001563.f02630.root',
#  'comb.debug.r001563.f04826.root',
#  'comb.debug.r001563.f00437.root',
#  'comb.debug.r001563.f03965.root',
#  'comb.debug.r001563.f01908.root',
#  'comb.debug.r001563.f03312.root',
#  'comb.debug.r001520.f00017.root',
#  'comb.debug.r001563.f04192.root',
#  'comb.debug.r001563.f00803.root',
#  'comb.debug.r001563.f02661.root',
#  'comb.debug.r001563.f01099.root',
#  'comb.debug.r001563.f01262.root',
#  'comb.debug.r001563.f01904.root',
#  'comb.debug.r001563.f01662.root',
#  'comb.debug.r001563.f02541.root',
#  'comb.debug.r001563.f01414.root',
#  'comb.debug.r001563.f03421.root',
#  'comb.debug.r001563.f00120.root',
#  'comb.debug.r001563.f00920.root',
#  'comb.debug.r001563.f04675.root',
#  'comb.debug.r001523.f00007.root',
#  'comb.debug.r001510.f00035.root',
#  'comb.debug.r001563.f03605.root',
#  'comb.debug.r001563.f01762.root',
#  'comb.debug.r001563.f01456.root',
#  'comb.debug.r001563.f00646.root',
#  'comb.debug.r001520.f00041.root',
#  'comb.debug.r001563.f04208.root',
#  'comb.debug.r001563.f00015.root',
#  'comb.debug.r001563.f01314.root',
#  'comb.debug.r001563.f01246.root',
#  'comb.debug.r001510.f00026.root',
#  'comb.debug.r001563.f02544.root',
#  'comb.debug.r001563.f02935.root',
#  'comb.debug.r001563.f02528.root',
#  'comb.debug.r001563.f00230.root',
#  'comb.debug.r001563.f03513.root',
#  'comb.debug.r001563.f04446.root',
#  'comb.debug.r001563.f02829.root',
#  'comb.debug.r001563.f03591.root',
#  'comb.debug.r001563.f02956.root',
#  'comb.debug.r001563.f04776.root',
#  'comb.debug.r001563.f04163.root',
#  'comb.debug.r001563.f00964.root',
#  'comb.debug.r001563.f00517.root',
#  'comb.debug.r001563.f01515.root',
#  'comb.debug.r001563.f00429.root',
#  'comb.debug.r001563.f01215.root',
#  'comb.debug.r001563.f00573.root',
#  'comb.debug.r001563.f01124.root',
#  'comb.debug.r001563.f00719.root',
#  'comb.debug.r001563.f02056.root',
#  'comb.debug.r001563.f02925.root',
#  'comb.debug.r001563.f04015.root',
#  'comb.debug.r001563.f00118.root',
#  'comb.debug.r001563.f02490.root',
#  'comb.debug.r001563.f00947.root',
#  'comb.debug.r001563.f03473.root',
#  'comb.debug.r001563.f00556.root',
#  'comb.debug.r001563.f04812.root',
#  'comb.debug.r001563.f02976.root',
#  'comb.debug.r001563.f02419.root',
#  'comb.debug.r001563.f02944.root',
#  'comb.debug.r001522.f00045.root',
#  'comb.debug.r001519.f00024.root',
#  'comb.debug.r001563.f04108.root',
#  'comb.debug.r001563.f01137.root',
#  'comb.debug.r001563.f01997.root',
#  'comb.debug.r001511.f00000.root',
#  'comb.debug.r001563.f02306.root',
#  'comb.debug.r001563.f00717.root',
#  'comb.debug.r001506.f00027.root',
#  'comb.debug.r001563.f01630.root',
#  'comb.debug.r001563.f01399.root',
#  'comb.debug.r001563.f00926.root',
#  'comb.debug.r001563.f01832.root',
#  'comb.debug.r001563.f04575.root',
#  'comb.debug.r001563.f02070.root',
#  'comb.debug.r001563.f03964.root',
#  'comb.debug.r001563.f03419.root',
#  'comb.debug.r001563.f02237.root',
#  'comb.debug.r001523.f00005.root',
#  'comb.debug.r001563.f02281.root',
#  'comb.debug.r001563.f00604.root',
#  'comb.debug.r001563.f04492.root',
#  'comb.debug.r001563.f01983.root',
#  'comb.debug.r001563.f00161.root',
#  'comb.debug.r001563.f03404.root',
#  'comb.debug.r001563.f04003.root',
#  'comb.debug.r001563.f00171.root',
#  'comb.debug.r001563.f01173.root',
#  'comb.debug.r001563.f01372.root',
#  'comb.debug.r001563.f01855.root',
#  'comb.debug.r001563.f02203.root',
#  'comb.debug.r001563.f03581.root',
#  'comb.debug.r001563.f03989.root',
#  'comb.debug.r001563.f02230.root',
#  'comb.debug.r001563.f04493.root',
#  'comb.debug.r001522.f00042.root',
#  'comb.debug.r001563.f03161.root',
#  'comb.debug.r001563.f01352.root',
#  'comb.debug.r001563.f01981.root',
#  'comb.debug.r001563.f02298.root',
#  'comb.debug.r001563.f01713.root',
#  'comb.debug.r001563.f04685.root',
#  'comb.debug.r001563.f02571.root',
#  'comb.debug.r001563.f02675.root',
#  'comb.debug.r001563.f04022.root',
#  'comb.debug.r001563.f04671.root',
#  'comb.debug.r001563.f00527.root',
#  'comb.debug.r001512.f00015.root',
#  'comb.debug.r001563.f04091.root',
#  'comb.debug.r001563.f00981.root',
#  'comb.debug.r001506.f00049.root',
#  'comb.debug.r001563.f00167.root',
#  'comb.debug.r001563.f01218.root',
#  'comb.debug.r001522.f00044.root',
#  'comb.debug.r001563.f00892.root',
#  'comb.debug.r001563.f00714.root',
#  'comb.debug.r001563.f00488.root',
#  'comb.debug.r001563.f04646.root',
#  'comb.debug.r001563.f00968.root',
#  'comb.debug.r001563.f04745.root',
#  'comb.debug.r001563.f01018.root',
#  'comb.debug.r001563.f02143.root',
#  'comb.debug.r001563.f01811.root',
#  'comb.debug.r001563.f01211.root',
#  'comb.debug.r001563.f00418.root',
#  'comb.debug.r001563.f02092.root',
#  'comb.debug.r001563.f00095.root',
#  'comb.debug.r001563.f03511.root',
#  'comb.debug.r001563.f03784.root',
#  'comb.debug.r001563.f04599.root',
#  'comb.debug.r001563.f00901.root',
#  'comb.debug.r001563.f04233.root',
#  'comb.debug.r001563.f01333.root',
#  'comb.debug.r001563.f04246.root',
#  'comb.debug.r001563.f00317.root',
#  'comb.debug.r001563.f04801.root',
#  'comb.debug.r001563.f00786.root',
#  'comb.debug.r001563.f04539.root',
#  'comb.debug.r001563.f03070.root',
#  'comb.debug.r001563.f01709.root',
#  'comb.debug.r001563.f00790.root',
#  'comb.debug.r001563.f04050.root',
#  'comb.debug.r001563.f03348.root',
#  'comb.debug.r001511.f00026.root',
#  'comb.debug.r001563.f00450.root',
#  'comb.debug.r001563.f04534.root',
#  'comb.debug.r001563.f00578.root',
#  'comb.debug.r001563.f01192.root',
#  'comb.debug.r001563.f01453.root',
#  'comb.debug.r001563.f00913.root',
#  'comb.debug.r001563.f01482.root',
#  'comb.debug.r001563.f02322.root',
#  'comb.debug.r001521.f00033.root',
#  'comb.debug.r001563.f03064.root',
#  'comb.debug.r001563.f01153.root',
#  'comb.debug.r001563.f01457.root',
#  'comb.debug.r001563.f02364.root',
#  'comb.debug.r001563.f00743.root',
#  'comb.debug.r001519.f00012.root',
#  'comb.debug.r001563.f02220.root',
#  'comb.debug.r001563.f00742.root',
#  'comb.debug.r001506.f00046.root',
#  'comb.debug.r001563.f04624.root',
#  'comb.debug.r001563.f04270.root',
#  'comb.debug.r001563.f00822.root',
#  'comb.debug.r001563.f00492.root',
#  'comb.debug.r001563.f00985.root',
#  'comb.debug.r001563.f02625.root',
#  'comb.debug.r001563.f04744.root',
#  'comb.debug.r001563.f00770.root',
#  'comb.debug.r001563.f04311.root',
#  'comb.debug.r001563.f01565.root',
#  'comb.debug.r001563.f03638.root',
#  'comb.debug.r001563.f00339.root',
#  'comb.debug.r001563.f03164.root',
#  'comb.debug.r001512.f00043.root',
#  'comb.debug.r001563.f00062.root',
#  'comb.debug.r001563.f03261.root',
#  'comb.debug.r001563.f02671.root',
#  'comb.debug.r001511.f00045.root',
#  'comb.debug.r001563.f02906.root',
#  'comb.debug.r001563.f01223.root',
#  'comb.debug.r001563.f00390.root',
#  'comb.debug.r001563.f01641.root',
#  'comb.debug.r001563.f03736.root',
#  'comb.debug.r001563.f00226.root',
#  'comb.debug.r001563.f02275.root',
#  'comb.debug.r001521.f00042.root',
#  'comb.debug.r001563.f00385.root',
#  'comb.debug.r001563.f02535.root',
#  'comb.debug.r001506.f00013.root',
#  'comb.debug.r001563.f01716.root',
#  'comb.debug.r001563.f02930.root',
#  'comb.debug.r001520.f00006.root',
#  'comb.debug.r001513.f00019.root',
#  'comb.debug.r001563.f00760.root',
#  'comb.debug.r001563.f03539.root',
#  'comb.debug.r001563.f04209.root',
#  'comb.debug.r001563.f01654.root',
#  'comb.debug.r001563.f04129.root',
#  'comb.debug.r001563.f02615.root',
#  'comb.debug.r001563.f01944.root',
#  'comb.debug.r001563.f01327.root',
#  'comb.debug.r001563.f00856.root',
#  'comb.debug.r001563.f00528.root',
#  'comb.debug.r001563.f03575.root',
#  'comb.debug.r001563.f03373.root',
#  'comb.debug.r001563.f04011.root',
#  'comb.debug.r001563.f04451.root',
#  'comb.debug.r001563.f01503.root',
#  'comb.debug.r001563.f04132.root',
#  'comb.debug.r001563.f00249.root',
#  'comb.debug.r001563.f02636.root',
#  'comb.debug.r001509.f00048.root',
#  'comb.debug.r001563.f00180.root',
#  'comb.debug.r001563.f00791.root',
#  'comb.debug.r001563.f02199.root',
#  'comb.debug.r001563.f03510.root',
#  'comb.debug.r001563.f01789.root',
#  'comb.debug.r001563.f02677.root',
#  'comb.debug.r001563.f04547.root',
#  'comb.debug.r001519.f00036.root',
#  'comb.debug.r001563.f03533.root',
#  'comb.debug.r001563.f04778.root',
#  'comb.debug.r001563.f00780.root',
#  'comb.debug.r001563.f02775.root',
#  'comb.debug.r001563.f04374.root',
#  'comb.debug.r001563.f03744.root',
#  'comb.debug.r001563.f02426.root',
#  'comb.debug.r001563.f03717.root',
#  'comb.debug.r001563.f01444.root',
#  'comb.debug.r001563.f02897.root',
#  'comb.debug.r001563.f03405.root',
#  'comb.debug.r001563.f04113.root',
#  'comb.debug.r001563.f02006.root',
#  'comb.debug.r001563.f00408.root',
#  'comb.debug.r001509.f00026.root',
#  'comb.debug.r001563.f01130.root',
#  'comb.debug.r001563.f04119.root',
#  'comb.debug.r001563.f04849.root',
#  'comb.debug.r001563.f04326.root',
#  'comb.debug.r001563.f04398.root',
#  ...]

# %%
run_nums = [1506, 1509, 1510, 1511, 1512, 1513, 1517, 1518, 1519, 1520,1521,1522,1523]
real_vtxs = [1.218, 1.156, 1.010, 0.752, 0.508, 0.251, 0.007, -0.249, -0.494, -0.751, -0.996, -1.142, -1.216]



for runs in range(len(run_nums)):
    run_num = run_nums[runs]
    
    
    
    
    
    for i in range(53):
        energy_all=[]
        x_all=[]
        y_all=[]
        z_all=[]
        dT_all = []
        dV_all = []
        PC_all = []
        vtx_all = []
        data_file = path + 'comb.debug.r00'+str(run_num)+'.f'+ '{0:05d}'.format(i)+'.root'

        real_vtx = real_vtxs[runs]
#         if files[i].split('.')[2][3:] == str(run_num):
#             file_id = files[i].split('.')[-2][-5:]
            
        file = uproot.open(path + files[i])

        for j in range(len(np.array(file['comTree']['Var1']))):
            energy = (np.array(file['comTree']['RecoFlux'])/(5200/8))[j]
            vtx = np.array(file['comTree']['RecoVertex']).T[:,j]
            dT = np.array(file['comTree']['Var1'])[j]
            dV = np.array(file['comTree']['Var2'])[j]
            PC = np.array(file['comTree']['PMTCharge'])[j]
            energy_all.append(energy)
            vtx_all.append(np.array([0,0,real_vtx]))

            x_all.append(vtx[0])
            y_all.append(vtx[1])
            z_all.append(vtx[2])
            dT_all.append(dT)
            dV_all.append(dV)
            PC_all.append(PC)

                
                
                
        selec = ((np.abs(np.array(z_all)) < 1.25) & (np.array(energy_all) >6) &(np.array(energy_all) < 10))
        XX = np.array(x_all)[selec]
        YY = np.array(y_all)[selec]
        ZZ = np.array(z_all)[selec]
        pmts_charge = np.array(PC_all)[selec].reshape(-1,96,1)
        real_vtx = np.array(vtx_all)[selec]

        jade_vtx = np.concatenate((XX.reshape(-1,1),YY.reshape(-1,1),ZZ.reshape(-1,1)),axis = 1)
        print(runs, i, j)
        kwargs = {'dtype':'f4', 'compression':'lzf'}
        #     with h5py.File(output_path, 'w', libver='latest', swmr=True) as fout:
        output = '/store/hep/users/yewzzang/JSNS2/cf_data_pair/'+ 'r00'+str(run_num)+'_cf_data_'+ str(i) +'.h5'
    #         output = '/store/hep/users/yewzzang/JSNS2/cf_data_pair_10to60/'+ 'r00'+str(run_num)+'_cf_data_'+ str(i) +'.h5'

        with h5py.File(output, 'w', libver='latest', swmr=True) as fout:

            g = fout.create_group('events')
            g.create_dataset('jade_vtx', data=jade_vtx, chunks=(1,3),**kwargs)
            g.create_dataset('real_vtx', data=real_vtx, chunks=(1,3),**kwargs)
            g.create_dataset('pmt_charge',data=pmts_charge,chunks=(1,96,1),**kwargs)


# for i in range(len(files)):
#     if files[i].split('.')[2][3:] == '1563':
#         continue

#     file = uproot.open(path + files[i])

#     for j in range(len(np.array(file['comTree']['Var1']))):
#         energy = (np.array(file['comTree']['RecoFlux'])/(5200/8))[j]
#         vtx = np.array(file['comTree']['RecoVertex']).T[:,j]
#         dT = np.array(file['comTree']['Var1'])[j]
#         dV = np.array(file['comTree']['Var2'])[j]
#         energy_all.append(energy)
#         x_all.append(vtx[0])
#         y_all.append(vtx[1])
#         z_all.append(vtx[2])
#         dT_all.append(dT)
#         dV_all.append(dV)
# Out:
# 0 0 38
# 0 1 31
# 0 2 26
# 0 3 26
# 0 4 25
# 0 5 25
# 0 6 32
# 0 7 24
# 0 8 34
# 0 9 30
# 0 10 37
# 0 11 36
# 0 12 23
# 0 13 28
# 0 14 28
# 0 15 40
# 0 16 22
# 0 17 26
# 0 18 32
# 0 19 23
# 0 20 31
# 0 21 23
# 0 22 38
# 0 23 24
# 0 24 36
# 0 25 39
# 0 26 17
# 0 27 28
# 0 28 23
# 0 29 37
# 0 30 18
# 0 31 28
# 0 32 26
# 0 33 49
# 0 34 20
# 0 35 24
# 0 36 29
# 0 37 23
# 0 38 29
# 0 39 23
# 0 40 29
# 0 41 36
# 0 42 39
# 0 43 19
# 0 44 26
# 0 45 48
# 0 46 40
# 0 47 37
# 0 48 21
# 0 49 25
# 0 50 22
# 0 51 30
# 0 52 19
# 1 0 38
# 1 1 31
# 1 2 26
# 1 3 26
# 1 4 25
# 1 5 25
# 1 6 32
# 1 7 24
# 1 8 34
# 1 9 30
# 1 10 37
# 1 11 36
# 1 12 23
# 1 13 28
# 1 14 28
# 1 15 40
# 1 16 22
# 1 17 26
# 1 18 32
# 1 19 23
# 1 20 31
# 1 21 23
# 1 22 38
# 1 23 24
# 1 24 36
# 1 25 39
# 1 26 17
# 1 27 28
# 1 28 23
# 1 29 37
# 1 30 18
# 1 31 28
# 1 32 26
# 1 33 49
# 1 34 20
# 1 35 24
# 1 36 29
# 1 37 23
# 1 38 29
# 1 39 23
# 1 40 29
# 1 41 36
# 1 42 39
# 1 43 19
# 1 44 26
# 1 45 48
# 1 46 40
# 1 47 37
# 1 48 21
# 1 49 25
# 1 50 22
# 1 51 30
# 1 52 19
# 2 0 38
# 2 1 31
# 2 2 26
# 2 3 26
# 2 4 25
# 2 5 25
# 2 6 32
# 2 7 24
# 2 8 34
# 2 9 30
# 2 10 37
# 2 11 36
# 2 12 23
# 2 13 28
# 2 14 28
# 2 15 40
# 2 16 22
# 2 17 26
# 2 18 32
# 2 19 23
# 2 20 31
# 2 21 23
# 2 22 38
# 2 23 24
# 2 24 36
# 2 25 39
# 2 26 17
# 2 27 28
# 2 28 23
# 2 29 37
# 2 30 18
# 2 31 28
# 2 32 26
# 2 33 49
# 2 34 20
# 2 35 24
# 2 36 29
# 2 37 23
# 2 38 29
# 2 39 23
# 2 40 29
# 2 41 36
# 2 42 39
# 2 43 19
# 2 44 26
# 2 45 48
# 2 46 40
# 2 47 37
# 2 48 21
# 2 49 25
# 2 50 22
# 2 51 30
# 2 52 19
# 3 0 38
# 3 1 31
# 3 2 26
# 3 3 26
# 3 4 25
# 3 5 25
# 3 6 32
# 3 7 24
# 3 8 34
# 3 9 30
# 3 10 37
# 3 11 36
# 3 12 23
# 3 13 28
# 3 14 28
# 3 15 40
# 3 16 22
# 3 17 26
# 3 18 32
# 3 19 23
# 3 20 31
# 3 21 23
# 3 22 38
# 3 23 24
# 3 24 36
# 3 25 39
# 3 26 17
# 3 27 28
# 3 28 23
# 3 29 37
# 3 30 18
# 3 31 28
# 3 32 26
# 3 33 49
# 3 34 20
# 3 35 24
# 3 36 29
# 3 37 23
# 3 38 29
# 3 39 23
# 3 40 29
# 3 41 36
# 3 42 39
# 3 43 19
# 3 44 26
# 3 45 48
# 3 46 40
# 3 47 37
# 3 48 21
# 3 49 25
# 3 50 22
# 3 51 30
# 3 52 19
# 4 0 38
# 4 1 31
# 4 2 26
# 4 3 26
# 4 4 25
# 4 5 25
# 4 6 32
# 4 7 24
# 4 8 34
# 4 9 30
# 4 10 37
# 4 11 36
# 4 12 23
# 4 13 28
# 4 14 28
# 4 15 40
# 4 16 22
# 4 17 26
# 4 18 32
# 4 19 23
# 4 20 31
# 4 21 23
# 4 22 38
# 4 23 24
# 4 24 36
# 4 25 39
# 4 26 17
# 4 27 28
# 4 28 23
# 4 29 37
# 4 30 18
# 4 31 28
# 4 32 26
# 4 33 49
# 4 34 20
# 4 35 24
# 4 36 29
# 4 37 23
# 4 38 29
# 4 39 23
# 4 40 29
# 4 41 36
# 4 42 39
# 4 43 19
# 4 44 26
# 4 45 48
# 4 46 40
# 4 47 37
# 4 48 21
# 4 49 25
# 4 50 22
# 4 51 30
# 4 52 19
# 5 0 38
# 5 1 31
# 5 2 26
# 5 3 26
# 5 4 25
# 5 5 25
# 5 6 32
# 5 7 24
# 5 8 34
# 5 9 30
# 5 10 37
# 5 11 36
# 5 12 23
# 5 13 28
# 5 14 28
# 5 15 40
# 5 16 22
# 5 17 26
# 5 18 32
# 5 19 23
# 5 20 31
# 5 21 23
# 5 22 38
# 5 23 24
# 5 24 36
# 5 25 39
# 5 26 17
# 5 27 28
# 5 28 23
# 5 29 37
# 5 30 18
# 5 31 28
# 5 32 26
# 5 33 49
# 5 34 20
# 5 35 24
# 5 36 29
# 5 37 23
# 5 38 29
# 5 39 23
# 5 40 29
# 5 41 36
# 5 42 39
# 5 43 19
# 5 44 26
# 5 45 48
# 5 46 40
# 5 47 37
# 5 48 21
# 5 49 25
# 5 50 22
# 5 51 30
# 5 52 19
# 6 0 38
# 6 1 31
# 6 2 26
# 6 3 26
# 6 4 25
# 6 5 25
# 6 6 32
# 6 7 24
# 6 8 34
# 6 9 30
# 6 10 37
# 6 11 36
# 6 12 23
# 6 13 28
# 6 14 28
# 6 15 40
# 6 16 22
# 6 17 26
# 6 18 32
# 6 19 23
# 6 20 31
# 6 21 23
# 6 22 38
# 6 23 24
# 6 24 36
# 6 25 39
# 6 26 17
# 6 27 28
# 6 28 23
# 6 29 37
# 6 30 18
# 6 31 28
# 6 32 26
# 6 33 49
# 6 34 20
# 6 35 24
# 6 36 29
# 6 37 23
# 6 38 29
# 6 39 23
# 6 40 29
# 6 41 36
# 6 42 39
# 6 43 19
# 6 44 26
# 6 45 48
# 6 46 40
# 6 47 37
# 6 48 21
# 6 49 25
# 6 50 22
# 6 51 30
# 6 52 19
# 7 0 38
# 7 1 31
# 7 2 26
# 7 3 26
# 7 4 25
# 7 5 25
# 7 6 32
# 7 7 24
# 7 8 34
# 7 9 30
# 7 10 37
# 7 11 36
# 7 12 23
# 7 13 28
# 7 14 28
# 7 15 40
# 7 16 22
# 7 17 26
# 7 18 32
# 7 19 23
# 7 20 31
# 7 21 23
# 7 22 38
# 7 23 24
# 7 24 36
# 7 25 39
# 7 26 17
# 7 27 28
# 7 28 23
# 7 29 37
# 7 30 18
# 7 31 28
# 7 32 26
# 7 33 49
# 7 34 20
# 7 35 24
# 7 36 29
# 7 37 23
# 7 38 29
# 7 39 23
# 7 40 29
# 7 41 36
# 7 42 39
# 7 43 19
# 7 44 26
# 7 45 48
# 7 46 40
# 7 47 37
# 7 48 21
# 7 49 25
# 7 50 22
# 7 51 30
# 7 52 19
# 8 0 38
# 8 1 31
# 8 2 26
# 8 3 26
# 8 4 25
# 8 5 25
# 8 6 32
# 8 7 24
# 8 8 34
# 8 9 30
# 8 10 37
# 8 11 36
# 8 12 23
# 8 13 28
# 8 14 28
# 8 15 40
# 8 16 22
# 8 17 26
# 8 18 32
# 8 19 23
# 8 20 31
# 8 21 23
# 8 22 38
# 8 23 24
# 8 24 36
# 8 25 39
# 8 26 17
# 8 27 28
# 8 28 23
# 8 29 37
# 8 30 18
# 8 31 28
# 8 32 26
# 8 33 49
# 8 34 20
# 8 35 24
# 8 36 29
# 8 37 23
# 8 38 29
# 8 39 23
# 8 40 29
# 8 41 36
# 8 42 39
# 8 43 19
# 8 44 26
# 8 45 48
# 8 46 40
# 8 47 37
# 8 48 21
# 8 49 25
# 8 50 22
# 8 51 30
# 8 52 19
# 9 0 38
# 9 1 31
# 9 2 26
# 9 3 26
# 9 4 25
# 9 5 25
# 9 6 32
# 9 7 24
# 9 8 34
# 9 9 30
# 9 10 37
# 9 11 36
# 9 12 23
# 9 13 28
# 9 14 28
# 9 15 40
# 9 16 22
# 9 17 26
# 9 18 32
# 9 19 23
# 9 20 31
# 9 21 23
# 9 22 38
# 9 23 24
# 9 24 36
# 9 25 39
# 9 26 17
# 9 27 28
# 9 28 23
# 9 29 37
# 9 30 18
# 9 31 28
# 9 32 26
# 9 33 49
# 9 34 20
# 9 35 24
# 9 36 29
# 9 37 23
# 9 38 29
# 9 39 23
# 9 40 29
# 9 41 36
# 9 42 39
# 9 43 19
# 9 44 26
# 9 45 48
# 9 46 40
# 9 47 37
# 9 48 21
# 9 49 25
# 9 50 22
# 9 51 30
# 9 52 19
# 10 0 38
# 10 1 31
# 10 2 26
# 10 3 26
# 10 4 25
# 10 5 25
# 10 6 32
# 10 7 24
# 10 8 34
# 10 9 30
# 10 10 37
# 10 11 36
# 10 12 23
# 10 13 28
# 10 14 28
# 10 15 40
# 10 16 22
# 10 17 26
# 10 18 32
# 10 19 23
# 10 20 31
# 10 21 23
# 10 22 38
# 10 23 24
# 10 24 36
# 10 25 39
# 10 26 17
# 10 27 28
# 10 28 23
# 10 29 37
# 10 30 18
# 10 31 28
# 10 32 26
# 10 33 49
# 10 34 20
# 10 35 24
# 10 36 29
# 10 37 23
# 10 38 29
# 10 39 23
# 10 40 29
# 10 41 36
# 10 42 39
# 10 43 19
# 10 44 26
# 10 45 48
# 10 46 40
# 10 47 37
# 10 48 21
# 10 49 25
# 10 50 22
# 10 51 30
# 10 52 19
# 11 0 38
# 11 1 31
# 11 2 26
# 11 3 26
# 11 4 25
# 11 5 25
# 11 6 32
# 11 7 24
# 11 8 34
# 11 9 30
# 11 10 37
# 11 11 36
# 11 12 23
# 11 13 28
# 11 14 28
# 11 15 40
# 11 16 22
# 11 17 26
# 11 18 32
# 11 19 23
# 11 20 31
# 11 21 23
# 11 22 38
# 11 23 24
# 11 24 36
# 11 25 39
# 11 26 17
# 11 27 28
# 11 28 23
# 11 29 37
# 11 30 18
# 11 31 28
# 11 32 26
# 11 33 49
# 11 34 20
# 11 35 24
# 11 36 29
# 11 37 23
# 11 38 29
# 11 39 23
# 11 40 29
# 11 41 36
# 11 42 39
# 11 43 19
# 11 44 26
# 11 45 48
# 11 46 40
# 11 47 37
# 11 48 21
# 11 49 25
# 11 50 22
# 11 51 30
# 11 52 19
# 12 0 38
# 12 1 31
# 12 2 26
# 12 3 26
# 12 4 25
# 12 5 25
# 12 6 32
# 12 7 24
# 12 8 34
# 12 9 30
# 12 10 37
# 12 11 36
# 12 12 23
# 12 13 28
# 12 14 28
# 12 15 40
# 12 16 22
# 12 17 26
# 12 18 32
# 12 19 23
# 12 20 31
# 12 21 23
# 12 22 38
# 12 23 24
# 12 24 36
# 12 25 39
# 12 26 17
# 12 27 28
# 12 28 23
# 12 29 37
# 12 30 18
# 12 31 28
# 12 32 26
# 12 33 49
# 12 34 20
# 12 35 24
# 12 36 29
# 12 37 23
# 12 38 29
# 12 39 23
# 12 40 29
# 12 41 36
# 12 42 39
# 12 43 19
# 12 44 26
# 12 45 48
# 12 46 40
# 12 47 37
# 12 48 21
# 12 49 25
# 12 50 22
# 12 51 30
# 12 52 19

# %%
real_vtx.shape
# Out:
# (487, 3)

# %%
run_num
# Out:
# 1523

# %%
stop
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-8-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
np.array(dT_all)

# %%
selec = ((np.abs(np.array(z_all)) < 1.25) & (np.array(energy_all) >6) &(np.array(energy_all) < 10))
# selec = ((np.abs(np.array(z_all)) < 1.25) & (np.abs(np.array(x_all)) < 0.5) & (np.abs(np.array(y_all)) < 0.5) & (np.array(energy_all) >3))
# selec = ((np.array(x_all)>-0.05)& (np.array(x_all)<0.05)& (np.array(y_all)>-0.05)& (np.array(y_all)<0.05))
# selec = ((np.array(energy_all) >6) &(np.array(energy_all) < 8))

# %%
print(len(np.array(dV_all)))
print(len(np.array(dV_all)[selec]))

# %%
plt.rcParams['figure.figsize'] = (15, 15)
plt.subplot(2,2,1)
plt.hist(np.array(x_all),bins=50)
plt.title('Jade X')
# plt.show()
plt.subplot(2,2,2)
plt.hist(np.array(y_all),bins=50)
plt.title('Jade Y')
# plt.show()
plt.subplot(2,2,3)
plt.hist(np.array(z_all),bins=50)
plt.title('Jade Z')
# plt.show()
plt.subplot(2,2,4)
plt.hist(np.array(energy_all),bins=50)
plt.title('Energy')
plt.show()

# %%
np.array(x_all)[selec].shape

# %%
plt.hist2d(np.array(x_all)[selec],np.array(y_all)[selec],bins=[20,20], range=[[-1.6,1.6],[-1.6,1.6]],norm = LogNorm())
plt.colorbar()
plt.xlabel('x',fontsize=25)
plt.ylabel('y',fontsize=25)
plt.show()


plt.rcParams['figure.figsize'] = (15, 15)
plt.subplot(2,2,1)
plt.hist(np.array(x_all)[selec],bins=50)
plt.title('Jade X')
# plt.show()
plt.subplot(2,2,2)
plt.hist(np.array(y_all)[selec],bins=50)
plt.title('Jade Y')
# plt.show()
plt.subplot(2,2,3)
plt.hist(np.array(z_all)[selec],bins=50)
plt.title('Jade Z')
# plt.show()
plt.subplot(2,2,4)
plt.hist(np.array(energy_all)[selec],bins=50)
plt.title('Energy')
plt.show()

# %%
XX = np.array(x_all)[selec]
YY = np.array(y_all)[selec]
ZZ = np.array(z_all)[selec]
pmts_charge = np.array(PC_all)[selec]

# %%
np.array(x_all).shape

# %%
# kwargs = {'dtype':'f4', 'compression':'lzf'}
# #     with h5py.File(output_path, 'w', libver='latest', swmr=True) as fout:

# with h5py.File(output, 'w', libver='latest', swmr=True) as fout:

#     g = fout.create_group('events')
#     g.create_dataset('jade_vtx', data=jade_vtx, chunks=(1,3),**kwargs)
#     g.create_dataset('real_vtx', data=real_vtx, chunks=(1,3),**kwargs)
#     g.create_dataset('pmt_charge',data=pmts_charge,chunks=(1,96,1),**kwargs)
