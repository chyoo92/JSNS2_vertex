# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import h5py

# %%
energy = 5

# %%
# ### MC data
# test = h5py.File('/users/yewzzang/work/make_mc_vertex/analysis/mc_data_1102/combined_10MeV_2.h5','r')
# vtx = np.array(test['events']['vertex'])
# pmt_charge = np.array(test['events']['pmtQ'])[:,0:96]

# %%
#### Cf data
test = h5py.File('/store/hep/users/yewzzang/JSNS2/cf_data/r001513_cf_data_00000.h5','r')
vtx = np.array(test['events']['real_vtx'])
pmt_charge = np.array(test['events']['pmt_charge'])

# %%
# #### run1563 data
# test = h5py.File('/store/hep/users/yewzzang/JSNS2/ch_1563_data/r001563_ch_data_00000.h5','r')
# vtx = np.array(test['events']['jade_vtx'])
# pmt_charge = np.array(test['events']['pmt_charge'])

# %%
pmt_charge.shape
# Out:
# (18934, 96, 1)

# %%
plt.hist(np.max(pmt_charge,axis=1),bins=1000)
plt.show()

# %%
plt.hist(np.average(pmt_charge,axis=1),bins=300)
plt.ylim([0,1000])
plt.show()

# %%
ff = pd.read_csv('jsns_geometry_pos.csv',header=0)
# ff = pd.read_csv('jsns_geometry_pos2.csv',header=0)
# ff = pd.read_csv('cylinder_geometry_pos.csv',header=0)
# ff = pd.read_csv('sphere_geometry_pos.csv',header=0)

# %%
### R2
diff = vtx.reshape(-1,1,3) - np.array(ff)/1000
diff2 = diff[:,:,0]*diff[:,:,0]+diff[:,:,1]*diff[:,:,1]+diff[:,:,2]*diff[:,:,2]

# %%
combined = np.concatenate([pmt_charge.reshape(-1,len(ff),1),diff2.reshape(-1,len(ff),1)],axis=2)
combined.shape
# Out:
# (18934, 96, 2)

# %%
# combined2 = np.concatenate([pmt_charge_max.reshape(-1,len(ff),1),diff2.reshape(-1,len(ff),1)],axis=2)

# %%
for i in range(10):
    plt.plot(combined[i,:,1],combined[i,:,0],'.r')
#     plt.plot(combined[i,:,1][combined[i,:,1]<2],combined[i,:,0][combined[i,:,1]<2],'.r')
#     plt.plot(combined[i,:,1],combined[i,:,0]/combined[i,:,0].sum(),'.r',label=str(len(ff)-len(combined[i,:,0][combined[i,:,0] == 0])))
#     plt.plot(combined2[i,:,1],combined2[i,:,0],'.b',label=str(len(ff)-len(combined2[i,:,0][combined2[i,:,0] == 0])))
    plt.legend(loc='best')
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
